# %% [markdown]
# ## Imports

# %%
import pandas as pd

# %% [markdown]
# ## Functions

# %%
def data_filter(df_raw, column1, df_filter, column2, name):
    
    """
    Filter the data from one dataset to only match the information present in another DF. 
    It checks both indexes are the same type, then filters and, finally, saves the new DF.  
    
    Parameters:
        df_raw (DataFrame): Dataframe with all the information.
        column1(str): Column used as index for the Raw Dataframe.
        df_filter (DataFrame): Dataframe to use as a filter.
        column2(str): Column used as index for the Filter Dataframe.
        name (str): Name for the new file.
        
    Returns:

        Filtered dataframe.
    
    """

    df_raw[column1] = df_raw[column1].astype(str)
    df_filter[column2] = df_filter[column2].astype(str)

    df_filtered = df_raw[df_raw[column1].isin(df_filter[column2])]
    df_filtered.to_csv(f'filtered_{name}_dataset.csv')
    
    return df_filtered

# %% [markdown]
# ## Extraction

# %%
raw = pd.read_csv(r'../data/raw/microbigge.csv')
ast_dataset = pd.read_csv(r'../data/interim/ast_dataset_abg.csv')

# %% [markdown]
# ## Visualization

# %%
raw.head()
# Out:
#          #Scientific name       Protein     BioSample         Isolate  \
# 0     Salmonella enterica  HAC6049176.1  SAMN02147121  PDT000000005.4
# 1     Salmonella enterica  HAC6044684.1  SAMN02147122  PDT000000006.4
# 2     Salmonella enterica  HAC6076697.1  SAMN02147123  PDT000000007.4
# 3  Listeria monocytogenes    MOA88727.1  SAMN02265470  PDT000000011.3
# 4  Listeria monocytogenes    MOA97367.1  SAMN02265455  PDT000000012.3
#
#               Contig   Start    Stop Strand Element symbol  \
# 0  DAAMCG010000001.1  236896  237147      -            asr
# 1  DAAMCH010000001.1  578563  579027      -           golS
# 2  DAAMCI010000001.1   13878   14993      +           iroB
# 3     SATG01000001.1  383828  385654      -           inlK
# 4     SATD01000001.1   37892   39721      +    inl-lmo0514
#
#                                         Element name       Type Scope  \
# 0       acid resistance repetitive basic protein Asr     STRESS  plus
# 1        Au(I) sensor transcriptional regulator GolS     STRESS  plus
# 2  salmochelin biosynthesis C-glycosyltransferase...  VIRULENCE  plus
# 3                            class 1 internalin InlK  VIRULENCE  plus
# 4      lmo0514 family class 1 internalin Inl-lmo0514  VIRULENCE  plus
#
#      Subtype Class Subclass  Method  % Coverage of reference  \
# 0       ACID   NaN      NaN     HMM                    100.0
# 1      METAL  GOLD     GOLD  EXACTP                    100.0
# 2  VIRULENCE   NaN      NaN  BLASTP                    100.0
# 3  VIRULENCE   NaN      NaN  BLASTP                    100.0
# 4  VIRULENCE   NaN      NaN  BLASTP                    100.0
#
#    % Identity to reference
# 0                    55.88
# 1                   100.00
# 2                    86.79
# 3                    90.62
# 4                    94.14

# %%
ast_dataset.head()
# Out:
#         uid                                              title     accession  \
# 0  46923997  Pathogen: clinical or host-associated sample f...  SAMN46923997
# 1  46841726  Pathogen: clinical or host-associated sample f...  SAMN46841726
# 2  46841725  Pathogen: clinical or host-associated sample f...  SAMN46841725
# 3  46841724  Pathogen: clinical or host-associated sample f...  SAMN46841724
# 4  46841723  Pathogen: clinical or host-associated sample f...  SAMN46841723
#
#          date publicationdate modificationdate  \
# 0  2025/02/20      2025/02/20       2025/02/20
# 1  2025/02/14      2025/02/14       2025/02/14
# 2  2025/02/14      2025/02/14       2025/02/14
# 3  2025/02/14      2025/02/14       2025/02/14
# 4  2025/02/14      2025/02/14       2025/02/14
#
#                                         organization  taxonomy  \
# 0  Rhode Island Department of Health State Health...       485
# 1        Instituto de Pesquisa Pele Pequeno Principe       573
# 2        Instituto de Pesquisa Pele Pequeno Principe       573
# 3        Instituto de Pesquisa Pele Pequeno Principe       573
# 4        Instituto de Pesquisa Pele Pequeno Principe       573
#
#                 organism            sourcesample  \
# 0  Neisseria gonorrhoeae  BioSample:SAMN46923997
# 1  Klebsiella pneumoniae  BioSample:SAMN46841726
# 2  Klebsiella pneumoniae  BioSample:SAMN46841725
# 3  Klebsiella pneumoniae  BioSample:SAMN46841724
# 4  Klebsiella pneumoniae  BioSample:SAMN46841723
#
#                                           sampledata  \
# 0  <BioSample access="public" publication_date="2...
# 1  <BioSample access="public" publication_date="2...
# 2  <BioSample access="public" publication_date="2...
# 3  <BioSample access="public" publication_date="2...
# 4  <BioSample access="public" publication_date="2...
#
#                                          identifiers            infraspecies  \
# 0  BioSample: SAMN46923997; Sample name: RISHL25N...  isolate: RISHL25NGS004
# 1        BioSample: SAMN46841726; Sample name: Kp181    isolate: K181 winter
# 2         BioSample: SAMN46841725; Sample name: K174    isolate: K174 autumn
# 3         BioSample: SAMN46841724; Sample name: K159    isolate: K159 spring
# 4         BioSample: SAMN46841723; Sample name: K158    isolate: K158 spring
#
#                                              package   sortkey  BioSample ID
# 0  Pathogen: clinical or host-associated; version...  20250220      46923997
# 1  Pathogen: clinical or host-associated; version...  20250214      46841726
# 2  Pathogen: clinical or host-associated; version...  20250214      46841725
# 3  Pathogen: clinical or host-associated; version...  20250214      46841724
# 4  Pathogen: clinical or host-associated; version...  20250214      46841723

# %% [markdown]
# ## Filter

# %%
filtered_df = data_filter(raw, "BioSample", ast_dataset, "accession", "genetic1")
filtered_df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 filtered_df = data_filter(raw, "BioSample", ast_dataset, "accession", "genetic1")
#       2 filtered_df.head()
#
# NameError: name 'data_filter' is not defined
